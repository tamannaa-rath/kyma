# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt

data = scipy.io.loadmat("../data/raw/normal_0.mat")

print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X097_DE_time', 'X097_FE_time', 'X097RPM'])

# %%
signal = data['X097_DE_time'].flatten()

print("Signal length:", len(signal))
# Out:
# Signal length: 243938

# %%
plt.figure(figsize=(12,4))
plt.plot(signal)
plt.title("Raw Vibration Signal (Healthy Bearing)")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()
